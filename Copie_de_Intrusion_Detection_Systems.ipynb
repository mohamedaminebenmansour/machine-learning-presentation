# %% [markdown]
# # **Intrusion Detection Systems**

# %% [markdown]
# ### Summary
#
# 1.   Introduction
# 2.   Business Understanding
# 2.   Data Understanding
# 4.   Data Preparation
# 5.   Modeling
# 6.   Evaluation
# 7.   Deployment

# %% [markdown]
# ## 1- Introduction

# %% [markdown]
# Embarking on a machine learning project can be an exhilarating journey filled with the promise of uncovering hidden patterns and extracting valuable insights from data. However, without a structured approach, this journey can quickly become a labyrinth of complexities. This is where the Cross-Industry Standard Process for Data Mining (CRISP-DM) emerges as a guiding light, illuminating the path towards successful machine learning endeavors.
#
# CRISP-DM, a widely recognized and versatile framework, provides a comprehensive roadmap for machine learning projects, encompassing six distinct phases:
#
#
# 1.   Business Understanding: This initial phase lays the foundation for the project, clearly defining the problem to be addressed, the target audience, and the desired outcomes.
# 2.   Data Understanding: Delving into the heart of the project, this phase involves collecting, cleaning, and exploring the data, ensuring its quality and suitability for modeling.
# 3.Data Preparation: Refining the data for analysis, this phase entails feature selection, data transformation, and handling missing values, preparing the data for the modeling process.
# 4.   Modeling: The crux of the project, this phase involves selecting, training, and evaluating machine learning models, seeking the most effective model for the task at hand.
# 5.   Evaluation: Assessing the model's performance, this phase scrutinizes the model's accuracy, robustness, and potential biases, ensuring its reliability.
# 6.   Deployment: Integrating the model into real-world applications, this phase involves integrating the model into business processes and monitoring its performance over time.
#
# ![CRISP-DM_Process_Diagram.png](data:image/png;base64,...)
#
#
# CRISP-DM's iterative nature allows for continuous refinement and adaptation throughout the project, ensuring alignment with evolving business requirements and data insights. By embracing CRISP-DM as your steadfast companion, you can transform your machine learning project from a mere aspiration into a resounding success

# %% [markdown]
# ## 2- Business Understanding

# %% [markdown]
# In today's interconnected world, organizations are constantly under attack from cyber threats. These attacks can range from simple malware infections to sophisticated attempts to steal sensitive data or disrupt critical operations. Intrusion Detection Systems (IDS) are a critical component of an organization's cybersecurity strategy, providing real-time monitoring of network traffic and system activity to identify and alert security teams to potential threats
# Objectives
#
# The primary objective of an IDS is to protect an organization's network and systems from unauthorized access, misuse, or denial of service. Specifically, an IDS should be able to:
#
#
# *   Detect: Identify suspicious activity or anomalous behavior that may indicate an intrusion attempt.
# *   Analyze: Analyze the detected events to determine the severity of the threat and potential impact on the organization.
# *   Alert: Notify security teams of detected threats in a timely manner to allow for appropriate response and mitigation.
#
# An IDS is considered successful if it can:
#
#
# *   Effectively detect a wide range of threats, including known and unknown attacks.
# *   Minimize false positives to avoid unnecessary disruptions to normal operations.
# *  Provide timely and accurate alerts to allow for rapid response and mitigation.
# *  Integrate seamlessly with existing security infrastructure.

# %% [markdown]
# ## 3- Data Understanding

# %% [markdown]
# The NSL-KDD dataset is a widely used benchmark dataset for intrusion detection systems (IDS). It is a modified version of the original KDD Cup 1999 dataset, addressing some of its limitations and improving its suitability for machine learning applications. The dataset consists of network connection records classified into five classes: normal, probe, denial-of-service (DoS), unauthorized access to root (U2R), and remote to local (R2L).
#
# Key Characteristics
#
# * Contains 41 features describing each network connection, including protocol type, service type, number of bytes, and duration.
#
# * Comprises 2,883,078 records, divided into a training set (2,376,781 records) and a testing set (506,297 records).

# %% [markdown]
# Table 1. Dataset Description
#
# Feature|Description
# -------|-----------------
# Duration|duration of connection(in seconds)
# protocol_type|type of protocol
# Service|Network type
# Flag|Flag status
# Src_bytes|Number of bytes transferred from source to destination
# Dst_bytes|Number of bytes transferred from destination to source
# Land|If connection is to same host land=1 else 0
# Wrong_fragment|Number of wrong fragments
# Urgent|Number of urgent packets
# Hot|Number of “hot” indicatorsh
# Num_failed_logins|Number of failed logins
# Logged_in|If logged in logged_in=1else 0
# num_compromised|Number of compromised conditions
# root_shell|If root shell is obtained root_shell=1 else 0
# su_attempted|If “su root” accesses su_attempted=1 else 0
# num_root|Number of accessed roots
# num_file_creations|Number of file creations
# num_shells|Number of shell prompt
# num_access_files|Number of operations on access files
# num_outbound_cmds|Number of outbound commands
# is_host_login|If login is hot is_host_login=1 else 0
# is_guest_login|If login is guest is_guest_login=1 else 0
# Count_No|Number of connections to the same host in last 2 seconds
# srv_count|Number of connections to the same service in last 2 seconds
# serror_rate|Percentage of connection with syn error
# srv_serror_rate|Percentage of connection with syn error
# rerror_rate|Percentage of connection with rej error
# srv_rerror_rate|Percentage of connection with rej error
# same_srv_rate|Percentage of connection of same service
# diff_srv_rate|Percentage of connection of different service
# srv_diff_host_rate|Percentage of connection of different hosts
# dst_host_count Number|of connections of same destination host
# dst_host_srv_count|Number of connections of same destination host and service
# dst_host_same_srv_rate|Percentage of connections having same destination host and service
# dst_host_diff_srv_rate|Percentage of connections having different service on current host
# dst_host_same_src_port_rate|Percentage of connections of current host having same src port
# dst_host_srv_diff_host_rate|Percentage of connection of same service and different hosts
# dst_host_serror_rate|Percentage of connections of current host having S0 error
# dst_host_srv_serror_rate|Percentage of connections of current host of a service having S0 error
# dst_host_rerror_rate|Percentage of connections of current host that have rst error
# dst_host_srv_rerror_rate|Percentage of connections of current host of service that have rst error
# xAttack|Type of attack

# %% [markdown]
# Includes five classes:
#
# 1. Normal: Represents normal network traffic.
# 2. Probe: Involves attempts to gather information about a network or system's vulnerabilities.
# 3. DoS: Aims to disrupt or disable network services or resources.
# 4. U2R: Attempts to gain unauthorized root access to a system.
# 5. R2L: Attempts to gain unauthorized access to a local network from a remote user.

# %% [markdown]
# Table 2. Distribution of attacks
#
# Class |Subclass
# ------|---------------------
# Normal|Represents normal network traffic.
# DoS |Neptune, back, land, pod, smurf, teardrop, mailbomb, apache2, processtable, udpstorm, worm
# U2R |buffer_overflow, loadmodule, perl, rootkit, ps, sqlattack, xterm
# R2L |ftp_write, guess_passwd, imap, multihop, phf, spy, warezclient, warezmaster, sendmail, named, snmpgetattack, snmpguess, xlock, xsnoop, httptunnel
# Probe| ipsweep, nmap, portsweep, satan, mscan, saint

# %% [markdown]
# Limitations
#
# The NSL-KDD dataset has some limitations:
#
# Represents a limited range of attack types: May not capture the full spectrum of modern cyberattacks.
#
# Contains outdated network traffic patterns: Reflects network activity from the late 1990s, which may not align with current network environments.
#
# Lacks real-time characteristics: Does not provide real-time network traffic data for continuous monitoring and evaluation.
#
# Overall, the NSL-KDD dataset remains a valuable benchmark for intrusion detection research and development, providing a structured dataset for evaluating and comparing IDS algorithms.
